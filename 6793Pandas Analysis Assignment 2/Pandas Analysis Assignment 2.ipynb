# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
import os
#print(os.getcwd())
#print(os.listdir(os.getcwd()))
data = pd.read_csv(r'C:\Users\user\Documents\Data Science\ADS\6793Pandas Analysis Assignment 2\WA_Fn-UseC_-HR-Employee-Attrition.csv')
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
display(data.isnull().any()) #looks for null values
# Out:
# Age                         False
# Attrition                   False
# BusinessTravel              False
# DailyRate                   False
# Department                  False
# DistanceFromHome            False
# Education                   False
# EducationField              False
# EmployeeCount               False
# EmployeeNumber              False
# EnvironmentSatisfaction     False
# Gender                      False
# HourlyRate                  False
# JobInvolvement              False
# JobLevel                    False
# JobRole                     False
# JobSatisfaction             False
# MaritalStatus               False
# MonthlyIncome               False
# MonthlyRate                 False
# NumCompaniesWorked          False
# Over18                      False
# OverTime                    False
# PercentSalaryHike           False
# PerformanceRating           False
# RelationshipSatisfaction    False
# StandardHours               False
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
# Age                         1470 non-null int64
# Attrition                   1470 non-null object
# BusinessTravel              1470 non-null object
# DailyRate                   1470 non-null int64
# Department                  1470 non-null object
# DistanceFromHome            1470 non-null int64
# Education                   1470 non-null int64
# EducationField              1470 non-null object
# EmployeeCount               1470 non-null int64
# EmployeeNumber              1470 non-null int64
# EnvironmentSatisfaction     1470 non-null int64
# Gender                      1470 non-null object
# HourlyRate                  1470 non-null int64
# JobInvolvement              1470 non-null int64
# JobLevel                    1470 non-null int64
# JobRole                     1470 non-null object
# JobSatisfaction             1470 non-null int64
# ...

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
for col in data.columns: 
    print(col)
# Out:
# Age
# Attrition
# BusinessTravel
# DailyRate
# Department
# DistanceFromHome
# Education
# EducationField
# EmployeeCount
# EmployeeNumber
# EnvironmentSatisfaction
# Gender
# HourlyRate
# JobInvolvement
# JobLevel
# JobRole
# JobSatisfaction
# MaritalStatus
# MonthlyIncome
# MonthlyRate
# NumCompaniesWorked
# Over18
# OverTime
# PercentSalaryHike
# PerformanceRating
# RelationshipSatisfaction
# StandardHours
# StockOptionLevel
# TotalWorkingYears
# TrainingTimesLastYear
# WorkLifeBalance
# YearsAtCompany
# YearsInCurrentRole
# YearsSinceLastPromotion
# YearsWithCurrManager

# %%
df_jobrole = data[['JobRole','DistanceFromHome','Attrition']]
df_jobrole.head()
# Out:
#                  JobRole  DistanceFromHome Attrition
# 0        Sales Executive                 1       Yes
# 1     Research Scientist                 8        No
# 2  Laboratory Technician                 2       Yes
# 3     Research Scientist                 3        No
# 4  Laboratory Technician                 2        No

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='JobRole', y='DistanceFromHome', hue='Attrition', data=df_jobrole)
plt.title("Rate of attrition by distance and job role")
plt.xlabel("Job Role")
plt.ylabel("Distance from Home")
# Out:
# Text(0, 0.5, 'Distance from Home')

# %%
attrition_yes = df_jobrole[['DistanceFromHome', 'JobRole', 'Attrition']][df_jobrole['Attrition'] == 'Yes']
attrition_no = df_jobrole[['DistanceFromHome', 'JobRole', 'Attrition']][df_jobrole['Attrition'] == 'No']
attrition_yes
# Out:
#       DistanceFromHome                JobRole Attrition
# 0                    1        Sales Executive       Yes
# 2                    2  Laboratory Technician       Yes
# 14                  24  Laboratory Technician       Yes
# 21                   9   Sales Representative       Yes
# 24                   6     Research Scientist       Yes
# ...                ...                    ...       ...
# 1438                 9   Sales Representative       Yes
# 1442                 1     Research Scientist       Yes
# 1444                 7  Laboratory Technician       Yes
# 1452                 1        Sales Executive       Yes
# 1461                28        Sales Executive       Yes
#
# [237 rows x 3 columns]

# %%
#keys = role for df_jobrole['JobRole'].unique(), df_jobrole.groupby(['Attrition'])
attyes = attrition_yes.groupby(['DistanceFromHome', 'JobRole']).count().reset_index()
attyes
# Out:
#      DistanceFromHome                    JobRole  Attrition
# 0                   1            Human Resources          1
# 1                   1      Laboratory Technician          4
# 2                   1     Manufacturing Director          1
# 3                   1         Research Scientist          7
# 4                   1            Sales Executive          6
# ..                ...                        ...        ...
# 107                29  Healthcare Representative          1
# 108                29      Laboratory Technician          1
# 109                29                    Manager          1
# 110                29         Research Scientist          1
# 111                29            Sales Executive          1
#
# [112 rows x 3 columns]

# %%
distance_yes = attrition_yes[['DistanceFromHome','Attrition']]
distypes = distance_yes.groupby(['DistanceFromHome']).count().reset_index()
distypes
# Out:
#     DistanceFromHome  Attrition
# 0                  1         26
# 1                  2         28
# 2                  3         14
# 3                  4          9
# 4                  5         10
# 5                  6          7
# 6                  7         11
# 7                  8         10
# 8                  9         18
# 9                 10         11
# 10                11          4
# 11                12          6
# 12                13          6
# 13                14          4
# 14                15          5
# 15                16          7
# 16                17          5
# 17                18          4
# 18                19          3
# 19                20          4
# 20                21          3
# 21                22          6
# 22                23          5
# 23                24         12
# 24                25          6
# 25                26          3
# 26                27          3
# 27                28          2
# ...

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='DistanceFromHome', y='Attrition', data=distypes)
plt.title("Rate of attrition by distance")
plt.xlabel("Distance")
plt.ylabel("No.of employees who stayed")
# Out:
# Text(0, 0.5, 'No.of employees who stayed')

# %%
role_yes = attrition_yes[['JobRole','Attrition']]
roletypes = role_yes.groupby(['JobRole']).count().reset_index()
roletypes
# Out:
#                      JobRole  Attrition
# 0  Healthcare Representative          9
# 1            Human Resources         12
# 2      Laboratory Technician         62
# 3                    Manager          5
# 4     Manufacturing Director         10
# 5          Research Director          2
# 6         Research Scientist         47
# 7            Sales Executive         57
# 8       Sales Representative         33

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='JobRole', y='Attrition', data=roletypes)
plt.title("Rate of attrition by Job Role")
plt.xlabel("Job Role")
plt.ylabel("No.of employees who stayed")
# Out:
# Text(0, 0.5, 'No.of employees who stayed')

# %%
distance_no = attrition_no[['DistanceFromHome','Attrition']]
distypesno = distance_no.groupby(['DistanceFromHome']).count().reset_index()
distypesno

#attrition_no.groupby(['DistanceFromHome', 'JobRole']).count()
# Out:
#     DistanceFromHome  Attrition
# 0                  1        182
# 1                  2        183
# 2                  3         70
# 3                  4         55
# 4                  5         55
# 5                  6         52
# 6                  7         73
# 7                  8         70
# 8                  9         67
# 9                 10         75
# 10                11         25
# 11                12         14
# 12                13         13
# 13                14         17
# 14                15         21
# 15                16         25
# 16                17         15
# 17                18         22
# 18                19         19
# 19                20         21
# 20                21         15
# 21                22         13
# 22                23         22
# 23                24         16
# 24                25         19
# 25                26         22
# 26                27          9
# 27                28         21
# ...

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='DistanceFromHome', y='Attrition', data=distypesno)
plt.title("Rate of attrition by distance")
plt.xlabel("Distance")
plt.ylabel("No.of employees who left")
# Out:
# Text(0, 0.5, 'No.of employees who left')

# %%
role_no = attrition_no[['JobRole','Attrition']]
roletypeno = role_no.groupby(['JobRole']).count().reset_index()
roletypeno
# Out:
#                      JobRole  Attrition
# 0  Healthcare Representative        122
# 1            Human Resources         40
# 2      Laboratory Technician        197
# 3                    Manager         97
# 4     Manufacturing Director        135
# 5          Research Director         78
# 6         Research Scientist        245
# 7            Sales Executive        269
# 8       Sales Representative         50

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='JobRole', y='Attrition', data=roletypeno)
plt.title("Rate of attrition by Job Role")
plt.xlabel("Job Role")
plt.ylabel("No.of employees who left")
# Out:
# Text(0, 0.5, 'No.of employees who left')

# %%
df_income = data[['Education','MonthlyIncome','Attrition']]
df_income.head()
# Out:
#    Education  MonthlyIncome Attrition
# 0          2           5993       Yes
# 1          1           5130        No
# 2          2           2090       Yes
# 3          4           2909        No
# 4          1           3468        No

# %%
dfincome_yes = df_income[['Education','MonthlyIncome','Attrition']][df_income['Attrition'] == 'Yes']
dfincome_no = df_income[['Education','MonthlyIncome','Attrition']][df_income['Attrition'] == 'No'] 
dfincome_yes
# Out:
#       Education  MonthlyIncome Attrition
# 0             2           5993       Yes
# 2             2           2090       Yes
# 14            3           2028       Yes
# 21            4           3407       Yes
# 24            1           2960       Yes
# ...         ...            ...       ...
# 1438          3           1790       Yes
# 1442          4           4787       Yes
# 1444          2           2339       Yes
# 1452          4           6728       Yes
# 1461          3          10854       Yes
#
# [237 rows x 3 columns]

# %%
dfincome_yes.groupby(['Education']).mean()
# Out:
#            MonthlyIncome
# Education
# 1            4360.161290
# 2            4282.545455
# 3            4770.242424
# 4            5335.155172
# 5            5850.200000

# %%
dfincome_no.groupby(['Education']).mean()
# Out:
#            MonthlyIncome
# Education
# 1            5926.129496
# 2            6586.058824
# 3            6882.919662
# 4            7087.814706
# 5            8559.906977
